# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd


excel_path = "/content/drive/MyDrive/Online retail.xlsx"

df = pd.read_excel(excel_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                                burgers,meatballs,eggs
# 1                                               chutney
# 2                                        turkey,avocado
# 3     mineral water,milk,energy bar,whole wheat rice...
# 4                                        low fat yogurt
# ...                                                 ...
# 7495                      butter,light mayo,fresh bread
# ...

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                             burgers,meatballs,eggs
# 1                                            chutney
# 2                                     turkey,avocado
# 3  mineral water,milk,energy bar,whole wheat rice...
# 4                                     low fat yogurt

# %%
#Establishing the number of columns we have

print(df.columns.to_list())
print(len(df.columns))
# Out:
# ['shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil']
# 1
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.rename(columns={df.columns[0]: 'Purchased items'}, inplace=True)
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                      Purchased items
# 0                             burgers,meatballs,eggs
# 1                                            chutney
# 2                                     turkey,avocado
# 3  mineral water,milk,energy bar,whole wheat rice...
# 4                                     low fat yogurt

# %%
#Understanding the data type

print(df.dtypes)
# Out:
# Purchased items    object
# dtype: object
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#now get the info of the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Purchased items  7500 non-null   object
# dtypes: object(1)
# memory usage: 58.7+ KB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Assuming 'df' is your DataFrame containing the 'Purchased items' column
# Convert the 'Purchased items' column to a list of lists
transactions = df['Purchased items'].str.split(',').tolist()

# Convert the transaction data to the required format for the Apriori algorithm
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_transformed = pd.DataFrame(te_ary, columns=te.columns_)

# Apply the Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(df_transformed, min_support=0.01, use_colnames=True)

# Generate all association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Display all the association rules
print(rules)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                     antecedents                 consequents  \
# 0                     (avocado)             (mineral water)
# 1               (mineral water)                   (avocado)
# 2                     (burgers)                      (cake)
# 3                        (cake)                   (burgers)
# 4                     (burgers)                 (chocolate)
# ..                          ...                         ...
# 403  (spaghetti, mineral water)                  (pancakes)
# 404   (pancakes, mineral water)                 (spaghetti)
# 405                 (spaghetti)   (pancakes, mineral water)
# ...

# %%
# Setting the thresholds for support, confidence, and lift
min_support = 0.01
min_confidence = 0.5
min_lift = 1.2

# Filter the rules based on the thresholds
filtered_rules = rules[(rules['support'] >= min_support) &
                        (rules['confidence'] >= min_confidence) &
                        (rules['lift'] >= min_lift)]

# Display the filtered rules
print(filtered_rules)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#              antecedents      consequents  antecedent support  \
# 345  (eggs, ground beef)  (mineral water)               0.020
# 379  (milk, ground beef)  (mineral water)               0.022
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 345            0.238267  0.010133    0.506667  2.126469  0.005368    1.544054
# 379            0.238267  0.011067    0.503030  2.111207  0.005825    1.532756
#
#      zhangs_metric
# 345       0.540548
# 379       0.538177

# %%
#These are the association rules that meet the specified thresholds:

#(1) If a customer buys eggs and ground beef, they are 50.67% likely to also buy mineral water.
#This rule has a lift of 2.13, indicating a significant relationship between the antecedent and consequent.

#(2)If a customer buys milk and ground beef, they are 50.30% likely to also buy mineral water.
# This rule has a lift of 2.11, indicating a significant relationship between the antecedent and consequent.

#These rules have a support of at least 1%, confidence of at least 50%, and lift of at least 1.2.
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Interpreting the results and provide insights into customer purchasing behaviour based on the discovered rules.

#The analysis of the generated rules reveals several interesting patterns and relationships between the products:

#1.Strong Association between Eggs, Ground Beef, and Mineral Water:

#The rule with the highest confidence (50.67%) indicates that customers who purchase eggs and ground beef are highly likely (50.67%) to also buy mineral water. This suggests a strong association between these three products, possibly indicating that these items are frequently purchased together for a specific meal or occasion.

#2.Similar Association between Milk, Ground Beef, and Mineral Water:

#Another rule with high confidence (50.30%) shows that customers who buy milk and ground beef are also likely to purchase mineral water. This further reinforces the association between ground beef and mineral water, suggesting that these products are commonly bought together.

#3.High Lift for Eggs and Mineral Water:

#The rule involving eggs and mineral water has a lift of 2.13, indicating that the co-occurrence of these two products is significantly higher than what would be expected by chance. This suggests a strong relationship between these items, possibly indicating that customers who buy eggs are more likely to purchase mineral water as a complementary item.

#4.High Lift for Milk and Mineral Water:

#Similarly, the rule involving milk and mineral water has a lift of 2.11, suggesting a strong association between these products. This indicates that customers who buy milk are more likely to also buy mineral water, possibly indicating a complementary relationship between these items.

#5.Insights into Customer Purchasing Behavior:

#These discovered rules provide insights into customer purchasing behavior by identifying frequent combinations of products. This information can be utilized by retailers to improve product placement, design marketing strategies, and offer targeted promotions to increase sales and customer satisfaction.

#For example, retailers can place eggs, ground beef, and mineral water near each other in the store to encourage customers to purchase these items together. Additionally, they can offer bundle discounts or promotions on these products to further incentivize customers to buy them together.
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
